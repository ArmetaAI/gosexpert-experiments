# %% [markdown]
# # Download Analysis
# Analyze downloaded PDFs from download_status.csv

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# Load the clean CSV
df = pd.read_csv('download_status_clean.csv', encoding='utf-8')

print(f"Total records: {len(df)}")
print(f"\nColumns: {list(df.columns)}")

del df['file_number']
del df['file_size_mb']
df.head(10)
# Out:
# Total records: 564
#
# Columns: ['tag_short_name', 'filename', 'file_number', 'file_size_mb']
#                                       tag_short_name  \
# 0  Архитектурно-планировочное задание местно_0b7a...
# 1  Архитектурно-планировочное задание местно_0b7a...
# 2  Архитектурно-планировочное задание местно_0b7a...
# 3  Архитектурно-планировочное задание местно_0b7a...
# 4  Архитектурно-планировочное задание местно_0b7a...
# 5  Архитектурно-планировочное задание местно_0b7a...
# 6  Архитектурно-планировочное задание местно_0b7a...
# 7  Архитектурно-планировочное задание местно_0b7a...
# 8  Архитектурно-планировочное задание местно_0b7a...
# 9  Архитектурно-планировочное задание местно_0d05...
#
#                                             filename
# 0  Архитектурно-планировочное задание местно_0b7a...
# 1  Архитектурно-планировочное задание местно_0b7a...
# 2  Архитектурно-планировочное задание местно_0b7a...
# 3  Архитектурно-планировочное задание местно_0b7a...
# 4  Архитектурно-планировочное задание местно_0b7a...
# 5  Архитектурно-планировочное задание местно_0b7a...
# 6  Архитектурно-планировочное задание местно_0b7a...
# 7  Архитектурно-планировочное задание местно_0b7a...
# 8  Архитектурно-планировочное задание местно_0b7a...
# 9  Архитектурно-планировочное задание местно_0d05...

# %%
import re

def remove_hash_suffix(tag):
    return re.sub(r'_[a-f0-9]{8}$', '', tag)

df['tag_normalized'] = df['tag_short_name'].apply(remove_hash_suffix)

summary = df.groupby('tag_normalized').agg({
    'filename': 'count',
}).round(2)

summary.columns = ['file_count']
summary = summary.sort_values('file_count', ascending=False)

print("=== Summary by Tag (Top 20) ===")
summary.head(60)
# Out:
# === Summary by Tag (Top 20) ===
#                                                     file_count
# tag_normalized
# Разрешение местных исполнительных органов                   25
# Тестовые файлы ОПЗ                                          24
# Разрешение на осуществление деятельности,                   21
# Архитектурно-планировочное задание местно                   18
# Лицензия генеральной проектной и субпроек                   15
# Материалы инженерно-геодезических изысканий                 15
# ИРД.ДефАкт                                                  14
# ИРД.ПравоЗемля                                              13
# ПСД.ПП                                                      13
# ПСД.ПОС                                                     13
# Письмо-заявка заказчика                                     13
# Эскизный проект                                             13
# Технические условия на электроснабжение                     13
# Информация о генпроектировщике (субпроектировщике)          11
# ИРД.ОтчетГеод                                               11
# ИРД.Авиация                                                 10
# ИРД.ТЗ                                                      10
# ИРД.СметаПИР                                                10
# ИРД.НС                                                      10
# ИРД.ЛецензияИ                                               10
# ИРД.АПЗ                                                     10
# Задание на проектирование                                   10
# ИРД.Письмозаявка                                            10
# ИРД.ЛецензияП                                               10
# Разрешение местных исполнительных органов на ис...          10
# ПСД.ЭП                                                      10
# Материалы инженерно-геологических изысканий                 10
# Задание на проектирование                                    9
# Технические условия на водоснабжение и канализацию           9
# Материалы инженерно-геологических изысканий                  9
# Информация о заказчике                                       9
# Письмо заказчика о начале строительства объекта              8
# Прочее                                                       8
# ИРД.ТУподключение                                            7
# ИРД.ОтчетГеол                                                7
# Расчет стоимости (проектно-изыскательных) работ              7
# Технические условия на теплоснабжение                        7
# Письмо об отсутствии сибиреязвенных захор                    6
# Протокол дозиметрического контроля                           6
# Согласование с городским и_или областным                     6
# Разрешение местных исполнительных органов на ис...           6
# Лицензия на изыскательную деятельность                       6
# Источник финансирования                                      5
# Материалы инженерно-геодезических изысканий                  5
# Протокол замеров плотности потока радона                     5
# ПСД.ОВОС                                                     5
# Расчет стоимости проектных (проектно-изыскатель...           5
# Заключение СЭС                                               4
# Технические условия на телефонизацию                         4
# Информация о заказчике                                       4
# Эскизный проект                                              4
# Технические условия на водоснабжение и канализа...           4
# Письмо заказчика о начале строительства объекта              4
# Источник финансирования                                      3
# Технические условия на ливневую канализацию                  3
# Технические условия на газоснабжение                         3
# Утвержденный заказчиком перечень материал                    3
# Расчет стоимости проектной (проектно-изыс                    2
# Расчет стоимости проектных (проектно-изыс                    2
# Согласование комитета по водным ресурсам                     2

# %%
pd.set_option('display.max_rows', None)
print(df['tag_normalized'].value_counts())
# Out:
# tag_normalized
# Разрешение местных исполнительных органов                                                                                                                             25
# Тестовые файлы ОПЗ                                                                                                                                                    24
# Разрешение на осуществление деятельности,                                                                                                                             21
# Архитектурно-планировочное задание местно                                                                                                                             18
# Лицензия генеральной проектной и субпроек                                                                                                                             15
# Материалы инженерно-геодезических изысканий                                                                                                                           15
# ИРД.ДефАкт                                                                                                                                                            14
# ПСД.ПОС                                                                                                                                                               13
# Письмо-заявка заказчика                                                                                                                                               13
# ИРД.ПравоЗемля                                                                                                                                                        13
# ПСД.ПП                                                                                                                                                                13
# Технические условия на электроснабжение                                                                                                                               13
# Эскизный проект                                                                                                                                                       13
# Информация о генпроектировщике (субпроектировщике)                                                                                                                    11
# ИРД.ОтчетГеод                                                                                                                                                         11
# ПСД.ЭП                                                                                                                                                                10
# ИРД.ЛецензияП                                                                                                                                                         10
# ИРД.ЛецензияИ                                                                                                                                                         10
# ИРД.Письмозаявка                                                                                                                                                      10
# Материалы инженерно-геологических изысканий                                                                                                                           10
# ИРД.НС                                                                                                                                                                10
# Задание на проектирование                                                                                                                                             10
# ИРД.АПЗ                                                                                                                                                               10
# ИРД.Авиация                                                                                                                                                           10
# Разрешение местных исполнительных органов на использование земельного участка (площади, трассы) или правоустанавливающий документ на земельный участок                10
# ИРД.СметаПИР                                                                                                                                                          10
# ИРД.ТЗ                                                                                                                                                                10
# Материалы инженерно-геологических изысканий                                                                                                                            9
# Задание на проектирование                                                                                                                                              9
# Информация о заказчике                                                                                                                                                 9
# Технические условия на водоснабжение и канализацию                                                                                                                     9
# Письмо заказчика о начале строительства объекта                                                                                                                        8
# Прочее                                                                                                                                                                 8
# Расчет стоимости (проектно-изыскательных) работ                                                                                                                        7
# Технические условия на теплоснабжение                                                                                                                                  7
# ИРД.ОтчетГеол                                                                                                                                                          7
# ИРД.ТУподключение                                                                                                                                                      7
# Письмо об отсутствии сибиреязвенных захор                                                                                                                              6
# Протокол дозиметрического контроля                                                                                                                                     6
# Разрешение местных исполнительных органов на использование земельного участка (площадки, трассы) или правоустанавливающий документ на земельный участок                6
# Согласование с городским и_или областным                                                                                                                               6
# Лицензия на изыскательную деятельность                                                                                                                                 6
# Источник финансирования                                                                                                                                                5
# Расчет стоимости проектных (проектно-изыскательных) работ                                                                                                              5
# Протокол замеров плотности потока радона                                                                                                                               5
# ПСД.ОВОС                                                                                                                                                               5
# Материалы инженерно-геодезических изысканий                                                                                                                            5
# Эскизный проект                                                                                                                                                        4
# Технические условия на телефонизацию                                                                                                                                   4
# Информация о заказчике                                                                                                                                                 4
# Заключение СЭС                                                                                                                                                         4
# Технические условия на водоснабжение и канализацию                                                                                                                     4
# Письмо заказчика о начале строительства объекта                                                                                                                        4
# Технические условия на ливневую канализацию                                                                                                                            3
# Источник финансирования                                                                                                                                                3
# Технические условия на газоснабжение                                                                                                                                   3
# Утвержденный заказчиком перечень материал                                                                                                                              3
# Согласование проектной документации на ст                                                                                                                              2
# Расчет стоимости проектной (проектно-изыс                                                                                                                              2
# Согласование комитета лесного хозяйства и                                                                                                                              2
# Согласование комитета по водным ресурсам                                                                                                                               2
# Лицензия генеральной проектной с субпрект                                                                                                                              2
# Заключение технического обследования                                                                                                                                   2
# Заключение экологической экспертизы                                                                                                                                    2
# Дефектный акт, составленный по результата                                                                                                                              2
# Технические условия на телефонизацию                                                                                                                                   2
# Расчет стоимости проектных (проектно-изыс                                                                                                                              2
# Заключение технического обследования                                                                                                                                   1
# Ведомость объемов работ                                                                                                                                                1
# Архитектурно-планировочное задание местного органа архитектуры и градостроительства (АПЗ)                                                                              1
# Информация о генпроектировщике                                                                                                                                         1
# Документ                                                                                                                                                               1
# Индивидуальный план поэтапной разработки                                                                                                                               1
# Протокол замеров плотности потока радона                                                                                                                               1
# Лицензия на изыскательскую деятельность                                                                                                                                1
# Лицензия на изыскательскую деятельность                                                                                                                                1
# Лицензия генеральной проектной и субпроектной организаций с приложениями к ней и указанием категории лицензиата, дающих право на данный вид проектной деятельности     1
# Протокол дозиметрического контроля                                                                                                                                     1
# Расчет предельной стоимости строительства                                                                                                                              1
# Рекомендации и требования по разделам _ИТ                                                                                                                              1
# Специальные технические условия (особые н                                                                                                                              1
# Согласование с городским и_или областным исполнительным органом                                                                                                        1
# Решение местного исполнительного органа (                                                                                                                              1
# Согласование Комитета по водным ресурсам                                                                                                                               1
# Специальные технические условия (особые нормы), согласованные местным исполнительным органом                                                                           1
# Технические условия на теплоснабжение                                                                                                                                  1
# Технические условия на электроснабжение                                                                                                                                1
# Утвержденный Заказчиком перечень материал                                                                                                                              1
# Name: count, dtype: int64

# %%
from rapidfuzz import fuzz, process
from document_config import get_tag_examples, get_tag_file_type, get_psd_tags, get_ird_tags

def allocate_document_tag(document_name, tag_examples, threshold=60):
    """
    Allocate a document tag based on fuzzy matching with examples.
    
    Parameters:
    - document_name: The name of the document to classify
    - tag_examples: Dictionary mapping tags to example document names
    - threshold: Minimum similarity score (0-100) to consider a match
    
    Returns:
    - Tuple of (tag, confidence_score, matched_example) or (None, 0, None) if no match
    """
    best_match = None
    best_score = 0
    best_tag = None
    best_example = None
    
    document_name_clean = document_name.strip()
    
    for tag, examples in tag_examples.items():
        # First, check if the tag itself matches (for exact or near-exact tag names)
        tag_score = fuzz.partial_ratio(document_name_clean.lower(), tag.lower())
        
        if tag_score > best_score:
            best_score = tag_score
            best_tag = tag
            best_example = f"[TAG: {tag}]"
        
        # Then check against all examples
        for example in examples:
            example_clean = example.strip()
            
            # Use multiple fuzzy matching strategies
            partial_score = fuzz.partial_ratio(document_name_clean.lower(), example_clean.lower())
            token_sort_score = fuzz.token_sort_ratio(document_name_clean.lower(), example_clean.lower())
            token_set_score = fuzz.token_set_ratio(document_name_clean.lower(), example_clean.lower())
            
            # Take the maximum score from all strategies
            max_score = max(partial_score, token_sort_score, token_set_score)
            
            if max_score > best_score:
                best_score = max_score
                best_tag = tag
                best_example = example_clean
    
    if best_score >= threshold:
        return best_tag, best_score, best_example
    else:
        return None, best_score, None

# Load document type configuration
tag_examples = get_tag_examples()

print("=== DOCUMENT TAG CONFIGURATION ===")
print(f"Total tags: {len(tag_examples)}")
print(f"ИРД tags: {len(get_ird_tags())}")
print(f"ПСД tags: {len(get_psd_tags())}")
print(f"\nПСД Tags: {', '.join(get_psd_tags())}")
# Out:
# === DOCUMENT TAG CONFIGURATION ===
# Total tags: 42
# ИРД tags: 36
# ПСД tags: 6
#
# ПСД Tags: ПП, ЭП, ОПЗ, ПОС, ОВОС, Спецразд

# %%
from document_config import get_tag_file_type

results = []

for idx, row in df.iterrows():
    tag_normalized = row['tag_normalized']
    tag, score, example = allocate_document_tag(tag_normalized, tag_examples)
    
    file_type = get_tag_file_type(tag) if tag else None
    
    results.append({
        'document_tag': tag,
        'confidence_score': score,
        'matched_example': example,
        'file_type': file_type
    })

# Add results to dataframe
results_df = pd.DataFrame(results)
df['document_tag'] = results_df['document_tag']
df['tag_confidence'] = results_df['confidence_score']
df['matched_example'] = results_df['matched_example']
df['file_type'] = results_df['file_type']

# Show statistics
print("=== DOCUMENT TAG ALLOCATION RESULTS ===")
print(f"Total documents: {len(df)}")
print(f"Documents with allocated tags: {df['document_tag'].notna().sum()}")
print(f"Documents without tags: {df['document_tag'].isna().sum()}")
print(f"\nAverage confidence score: {df['tag_confidence'].mean():.2f}")
print(f"Min confidence score: {df['tag_confidence'].min():.2f}")
print(f"Max confidence score: {df['tag_confidence'].max():.2f}")

print("\n=== FILE TYPE BREAKDOWN ===")
print(df['file_type'].value_counts())
print(f"\nTotal ИРД files: {(df['file_type'] == 'ИРД').sum()}")
print(f"Total ПСД files: {(df['file_type'] == 'ПСД').sum()}")

print("\n=== TAG DISTRIBUTION ===")
print(df['document_tag'].value_counts())

# Save the updated dataframe
df.to_csv('download_status_with_tags.csv', index=False, encoding='utf-8')
print("\n✓ Saved to download_status_with_tags.csv")
# Out:
# === DOCUMENT TAG ALLOCATION RESULTS ===
# Total documents: 564
# Documents with allocated tags: 564
# Documents without tags: 0
#
# Average confidence score: 97.86
# Min confidence score: 66.67
# Max confidence score: 100.00
#
# === FILE TYPE BREAKDOWN ===
# file_type
# ИРД    498
# ПСД     66
# Name: count, dtype: int64
#
# Total ИРД files: 498
# Total ПСД files: 66
#
# === TAG DISTRIBUTION ===
# document_tag
# Технические условия на подключение           54
# Лицензия                                     46
# АПЗ                                          34
# Авиация                                      31
# Отчет Геод                                   31
# Письмо о начале строительства                30
# ТЗ                                           29
# Отчет Геол                                   26
# Дополнительная (корректировка/капремонт)     26
# ОПЗ                                          24
# Письмо Заявка                                23
# Правоустанавливающие документы               17
# Эскизный проект                              17
# Дефектный акт                                16
# Смета ПИР                                    16
# Согласование                                 14
# ПП                                           13
# Информация о заказчике                       13
# ПОС                                          13
# Право на землю                               13
# Приказ ГИПа                                  12
# ЭП                                           10
# Смета                                        10
# Прочие документы                              9
# Экспертизы и заключения                       8
# Протокол дозиметрического контроля            7
# ОВОС                                          6
# Письмо по скотогильникам и сибирской язве     6
# Заключение СЭС                                4
# Заключение технического обследования          3
# СТУ                                           2
# Расчет предельной стоимости строительства     1
# Name: count, dtype: int64
#
# ✓ Saved to download_status_with_tags.csv
